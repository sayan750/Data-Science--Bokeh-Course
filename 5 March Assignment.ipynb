# %% [markdown]
# ### 1.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 2.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 3.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 4.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 5.

# %% [markdown]
# ![image.png](attachment:image.png)
